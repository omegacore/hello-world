# %%
import os
print os.getcwd()
import lxml.etree as etree
import xtiTranslator as xti

#Change the filename
filename='GA.xti'

#Do stuff to clean up the xml tree
tree = etree.parse(filename)
root = tree.getroot()
root = xti.CleanBoxes(root)
root = xti.SimplifyPdos(root)

#Print topology if you want
#xti.PrintTopology(root)

#Set verbosity (second arg) higher to watch it work
iqList = xti.IQList(root, 0)

for thing in iqList:
    print thing
# Out:
# C:\Users\wingless\Documents\GitHub\hello-world
# ---------------
# # Term 1 (EK1200)
# ---------------
# # Term 2 (EL3004)
# ---------------
# # Term 3 (EL3004)
# ---------------
# # Term 4 (EL3004)
# ---------------
# # Term 5 (EL3004)
# ---------------
# # Term 6 (EL4004)
# ---------------
# # Term 7 (EL1008)
# ---------------
# # Term 8 (EL1088)
# ---------------
# # Term 9 (EL1088)
# ---------------
# # Term 11 (EL2798)
# ---------------
# # Term 12 (EL2798)
# ---------------
# # Term 10 (EL1088)
# ---------------
# # Term 16 (EK1110)
# ---------------
# # EB3 (EP4374-0002)
# ---------------
# # EB4 (EP2339-0021)
# Working on box Term 1 (EK1200)
# Found EK1*, skipping
# Working on box Term 2 (EL3004)
# Working on pdo AI Standard Channel 1
# Working on entry Value
# Adding I_Term2_EL3004_Ch1 AT %I* : Int;
# Working on pdo AI Standard Channel 2
# Working on entry Value
# Adding I_Term2_EL3004_Ch2 AT %I* : Int;
# Working on pdo AI Standard Channel 3
# Working on entry Value
# Adding I_Term2_EL3004_Ch3 AT %I* : Int;
# Working on pdo AI Standard Channel 4
# Working on entry Value
# Adding I_Term2_EL3004_Ch4 AT %I* : Int;
# Working on box Term 3 (EL3004)
# Working on pdo AI Standard Channel 1
# Working on entry Value
# Adding I_Term3_EL3004_Ch1 AT %I* : Int;
# Working on pdo AI Standard Channel 2
# Working on entry Value
# Adding I_Term3_EL3004_Ch2 AT %I* : Int;
# Working on pdo AI Standard Channel 3
# Working on entry Value
# Adding I_Term3_EL3004_Ch3 AT %I* : Int;
# Working on pdo AI Standard Channel 4
# Working on entry Value
# Adding I_Term3_EL3004_Ch4 AT %I* : Int;
# Working on box Term 4 (EL3004)
# Working on pdo AI Standard Channel 1
# Working on entry Value
# Adding I_Term4_EL3004_Ch1 AT %I* : Int;
# Working on pdo AI Standard Channel 2
# Working on entry Value
# Adding I_Term4_EL3004_Ch2 AT %I* : Int;
# Working on pdo AI Standard Channel 3
# Working on entry Value
# Adding I_Term4_EL3004_Ch3 AT %I* : Int;
# Working on pdo AI Standard Channel 4
# Working on entry Value
# Adding I_Term4_EL3004_Ch4 AT %I* : Int;
# Working on box Term 5 (EL3004)
# Working on pdo AI Standard Channel 1
# Working on entry Value
# Adding I_Term5_EL3004_Ch1 AT %I* : Int;
# Working on pdo AI Standard Channel 2
# Working on entry Value
# Adding I_Term5_EL3004_Ch2 AT %I* : Int;
# Working on pdo AI Standard Channel 3
# Working on entry Value
# Adding I_Term5_EL3004_Ch3 AT %I* : Int;
# Working on pdo AI Standard Channel 4
# Working on entry Value
# Adding I_Term5_EL3004_Ch4 AT %I* : Int;
# Working on box Term 6 (EL4004)
# Working on pdo AO Outputs Channel 1
# Working on entry Analog output
# Adding Q_Term6_EL4004_Ch1 AT %Q* : Int;
# Working on pdo AO Outputs Channel 2
# Working on entry Analog output
# Adding Q_Term6_EL4004_Ch2 AT %Q* : Int;
# Working on pdo AO Outputs Channel 3
# Working on entry Analog output
# Adding Q_Term6_EL4004_Ch3 AT %Q* : Int;
# Working on pdo AO Outputs Channel 4
# Working on entry Analog output
# Adding Q_Term6_EL4004_Ch4 AT %Q* : Int;
# Working on box Term 7 (EL1008)
# Working on pdo Channel 1
# Working on entry Input
# Adding I_Term7_EL1008_Ch1 AT %I* : Bool;
# Working on pdo Channel 2
# Working on entry Input
# Adding I_Term7_EL1008_Ch2 AT %I* : Bool;
# Working on pdo Channel 3
# Working on entry Input
# Adding I_Term7_EL1008_Ch3 AT %I* : Bool;
# Working on pdo Channel 4
# Working on entry Input
# Adding I_Term7_EL1008_Ch4 AT %I* : Bool;
# Working on pdo Channel 5
# Working on entry Input
# Adding I_Term7_EL1008_Ch5 AT %I* : Bool;
# Working on pdo Channel 6
# Working on entry Input
# Adding I_Term7_EL1008_Ch6 AT %I* : Bool;
# Working on pdo Channel 7
# Working on entry Input
# Adding I_Term7_EL1008_Ch7 AT %I* : Bool;
# Working on pdo Channel 8
# Working on entry Input
# Adding I_Term7_EL1008_Ch8 AT %I* : Bool;
# Working on box Term 8 (EL1088)
# Working on pdo Channel 1
# Working on entry Input
# Adding I_Term8_EL1088_Ch1 AT %I* : Bool;
# Working on pdo Channel 2
# Working on entry Input
# Adding I_Term8_EL1088_Ch2 AT %I* : Bool;
# Working on pdo Channel 3
# Working on entry Input
# Adding I_Term8_EL1088_Ch3 AT %I* : Bool;
# Working on pdo Channel 4
# Working on entry Input
# Adding I_Term8_EL1088_Ch4 AT %I* : Bool;
# Working on pdo Channel 5
# Working on entry Input
# Adding I_Term8_EL1088_Ch5 AT %I* : Bool;
# Working on pdo Channel 6
# Working on entry Input
# Adding I_Term8_EL1088_Ch6 AT %I* : Bool;
# Working on pdo Channel 7
# Working on entry Input
# Adding I_Term8_EL1088_Ch7 AT %I* : Bool;
# Working on pdo Channel 8
# Working on entry Input
# Adding I_Term8_EL1088_Ch8 AT %I* : Bool;
# Working on box Term 9 (EL1088)
# Working on pdo Channel 1
# Working on entry Input
# Adding I_Term9_EL1088_Ch1 AT %I* : Bool;
# Working on pdo Channel 2
# Working on entry Input
# Adding I_Term9_EL1088_Ch2 AT %I* : Bool;
# Working on pdo Channel 3
# Working on entry Input
# Adding I_Term9_EL1088_Ch3 AT %I* : Bool;
# Working on pdo Channel 4
# Working on entry Input
# Adding I_Term9_EL1088_Ch4 AT %I* : Bool;
# Working on pdo Channel 5
# Working on entry Input
# Adding I_Term9_EL1088_Ch5 AT %I* : Bool;
# Working on pdo Channel 6
# Working on entry Input
# Adding I_Term9_EL1088_Ch6 AT %I* : Bool;
# Working on pdo Channel 7
# Working on entry Input
# Adding I_Term9_EL1088_Ch7 AT %I* : Bool;
# Working on pdo Channel 8
# Working on entry Input
# Adding I_Term9_EL1088_Ch8 AT %I* : Bool;
# Working on box Term 11 (EL2798)
# Working on pdo Channel 1
# Working on entry Output
# Adding Q_Term11_EL2798_Ch1 AT %Q* : Bool;
# Working on pdo Channel 2
# Working on entry Output
# Adding Q_Term11_EL2798_Ch2 AT %Q* : Bool;
# Working on pdo Channel 3
# Working on entry Output
# Adding Q_Term11_EL2798_Ch3 AT %Q* : Bool;
# Working on pdo Channel 4
# Working on entry Output
# Adding Q_Term11_EL2798_Ch4 AT %Q* : Bool;
# Working on pdo Channel 5
# Working on entry Output
# Adding Q_Term11_EL2798_Ch5 AT %Q* : Bool;
# Working on pdo Channel 6
# Working on entry Output
# Adding Q_Term11_EL2798_Ch6 AT %Q* : Bool;
# Working on pdo Channel 7
# Working on entry Output
# Adding Q_Term11_EL2798_Ch7 AT %Q* : Bool;
# Working on pdo Channel 8
# Working on entry Output
# Adding Q_Term11_EL2798_Ch8 AT %Q* : Bool;
# Working on box Term 12 (EL2798)
# Working on pdo Channel 1
# Working on entry Output
# Adding Q_Term12_EL2798_Ch1 AT %Q* : Bool;
# Working on pdo Channel 2
# Working on entry Output
# Adding Q_Term12_EL2798_Ch2 AT %Q* : Bool;
# Working on pdo Channel 3
# Working on entry Output
# Adding Q_Term12_EL2798_Ch3 AT %Q* : Bool;
# Working on pdo Channel 4
# Working on entry Output
# Adding Q_Term12_EL2798_Ch4 AT %Q* : Bool;
# Working on pdo Channel 5
# Working on entry Output
# Adding Q_Term12_EL2798_Ch5 AT %Q* : Bool;
# Working on pdo Channel 6
# Working on entry Output
# Adding Q_Term12_EL2798_Ch6 AT %Q* : Bool;
# Working on pdo Channel 7
# Working on entry Output
# Adding Q_Term12_EL2798_Ch7 AT %Q* : Bool;
# Working on pdo Channel 8
# Working on entry Output
# Adding Q_Term12_EL2798_Ch8 AT %Q* : Bool;
# Working on box Term 10 (EL1088)
# Working on pdo Channel 1
# Working on entry Input
# Adding I_Term10_EL1088_Ch1 AT %I* : Bool;
# Working on pdo Channel 2
# Working on entry Input
# Adding I_Term10_EL1088_Ch2 AT %I* : Bool;
# Working on pdo Channel 3
# Working on entry Input
# Adding I_Term10_EL1088_Ch3 AT %I* : Bool;
# Working on pdo Channel 4
# Working on entry Input
# Adding I_Term10_EL1088_Ch4 AT %I* : Bool;
# Working on pdo Channel 5
# Working on entry Input
# Adding I_Term10_EL1088_Ch5 AT %I* : Bool;
# Working on pdo Channel 6
# Working on entry Input
# Adding I_Term10_EL1088_Ch6 AT %I* : Bool;
# Working on pdo Channel 7
# Working on entry Input
# Adding I_Term10_EL1088_Ch7 AT %I* : Bool;
# Working on pdo Channel 8
# Working on entry Input
# Adding I_Term10_EL1088_Ch8 AT %I* : Bool;
# Working on box Term 16 (EK1110)
# Found EK1*, skipping
# Working on box EB3 (EP4374-0002)
# Working on pdo AI Inputs Channel 1
# Working on entry Value
# Adding I_EB3_EP4374_Ch1 AT %I* : Int;
# Working on pdo AI Inputs Channel 2
# Working on entry Value
# Adding I_EB3_EP4374_Ch2 AT %I* : Int;
# Working on pdo AO Outputs Channel 3
# Working on entry Analog output
# Adding Q_EB3_EP4374_Ch3 AT %Q* : Int;
# Working on pdo AO Outputs Channel 4
# Working on entry Analog output
# Adding Q_EB3_EP4374_Ch4 AT %Q* : Int;
# Working on box EB4 (EP2339-0021)
# Working on pdo Channel 1
# Working on entry Input
# Adding I_EB4_EP2339_Ch1 AT %I* : Bool;
# Working on pdo Channel 2
# Working on entry Input
# Adding I_EB4_EP2339_Ch2 AT %I* : Bool;
# Working on pdo Channel 3
# Working on entry Input
# Adding I_EB4_EP2339_Ch3 AT %I* : Bool;
# Working on pdo Channel 4
# Working on entry Input
# Adding I_EB4_EP2339_Ch4 AT %I* : Bool;
# Working on pdo Channel 5
# Working on entry Input
# Adding I_EB4_EP2339_Ch5 AT %I* : Bool;
# Working on pdo Channel 6
# Working on entry Input
# Adding I_EB4_EP2339_Ch6 AT %I* : Bool;
# Working on pdo Channel 7
# Working on entry Input
# Adding I_EB4_EP2339_Ch7 AT %I* : Bool;
# Working on pdo Channel 8
# Working on entry Input
# Adding I_EB4_EP2339_Ch8 AT %I* : Bool;
# Working on pdo Channel 9
# Working on entry Input
# Adding I_EB4_EP2339_Ch9 AT %I* : Bool;
# Working on pdo Channel 10
# Working on entry Input
# Adding I_EB4_EP2339_Ch10 AT %I* : Bool;
# Working on pdo Channel 11
# Working on entry Input
# Adding I_EB4_EP2339_Ch11 AT %I* : Bool;
# Working on pdo Channel 12
# Working on entry Input
# Adding I_EB4_EP2339_Ch12 AT %I* : Bool;
# Working on pdo Channel 13
# Working on entry Input
# Adding I_EB4_EP2339_Ch13 AT %I* : Bool;
# Working on pdo Channel 14
# Working on entry Input
# Adding I_EB4_EP2339_Ch14 AT %I* : Bool;
# Working on pdo Channel 15
# Working on entry Input
# Adding I_EB4_EP2339_Ch15 AT %I* : Bool;
# Working on pdo Channel 16
# Working on entry Input
# Adding I_EB4_EP2339_Ch16 AT %I* : Bool;
# Working on pdo Channel 17
# Working on entry Output
# Adding Q_EB4_EP2339_Ch17 AT %Q* : Bool;
# Working on pdo Channel 18
# Working on entry Output
# Adding Q_EB4_EP2339_Ch18 AT %Q* : Bool;
# Working on pdo Channel 19
# Working on entry Output
# Adding Q_EB4_EP2339_Ch19 AT %Q* : Bool;
# Working on pdo Channel 20
# Working on entry Output
# Adding Q_EB4_EP2339_Ch20 AT %Q* : Bool;
# Working on pdo Channel 21
# Working on entry Output
# Adding Q_EB4_EP2339_Ch21 AT %Q* : Bool;
# Working on pdo Channel 22
# Working on entry Output
# Adding Q_EB4_EP2339_Ch22 AT %Q* : Bool;
# Working on pdo Channel 23
# Working on entry Output
# Adding Q_EB4_EP2339_Ch23 AT %Q* : Bool;
# Working on pdo Channel 24
# Working on entry Output
# Adding Q_EB4_EP2339_Ch24 AT %Q* : Bool;
# Working on pdo Channel 25
# Working on entry Output
# Adding Q_EB4_EP2339_Ch25 AT %Q* : Bool;
# Working on pdo Channel 26
# Working on entry Output
# Adding Q_EB4_EP2339_Ch26 AT %Q* : Bool;
# Working on pdo Channel 27
# Working on entry Output
# Adding Q_EB4_EP2339_Ch27 AT %Q* : Bool;
# Working on pdo Channel 28
# Working on entry Output
# Adding Q_EB4_EP2339_Ch28 AT %Q* : Bool;
# Working on pdo Channel 29
# Working on entry Output
# Adding Q_EB4_EP2339_Ch29 AT %Q* : Bool;
# Working on pdo Channel 30
# Working on entry Output
# Adding Q_EB4_EP2339_Ch30 AT %Q* : Bool;
# Working on pdo Channel 31
# Working on entry Output
# Adding Q_EB4_EP2339_Ch31 AT %Q* : Bool;
# Working on pdo Channel 32
# Working on entry Output
# Adding Q_EB4_EP2339_Ch32 AT %Q* : Bool;
# //Term2_EL3004
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 2 (EL3004)^AI Standard Channel 1^Value'}
# I_Term2_EL3004_Ch1 AT %I* : Int;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 2 (EL3004)^AI Standard Channel 2^Value'}
# I_Term2_EL3004_Ch2 AT %I* : Int;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 2 (EL3004)^AI Standard Channel 3^Value'}
# I_Term2_EL3004_Ch3 AT %I* : Int;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 2 (EL3004)^AI Standard Channel 4^Value'}
# I_Term2_EL3004_Ch4 AT %I* : Int;
# //Term3_EL3004
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 3 (EL3004)^AI Standard Channel 1^Value'}
# I_Term3_EL3004_Ch1 AT %I* : Int;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 3 (EL3004)^AI Standard Channel 2^Value'}
# I_Term3_EL3004_Ch2 AT %I* : Int;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 3 (EL3004)^AI Standard Channel 3^Value'}
# I_Term3_EL3004_Ch3 AT %I* : Int;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 3 (EL3004)^AI Standard Channel 4^Value'}
# I_Term3_EL3004_Ch4 AT %I* : Int;
# //Term4_EL3004
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 4 (EL3004)^AI Standard Channel 1^Value'}
# I_Term4_EL3004_Ch1 AT %I* : Int;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 4 (EL3004)^AI Standard Channel 2^Value'}
# I_Term4_EL3004_Ch2 AT %I* : Int;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 4 (EL3004)^AI Standard Channel 3^Value'}
# I_Term4_EL3004_Ch3 AT %I* : Int;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 4 (EL3004)^AI Standard Channel 4^Value'}
# I_Term4_EL3004_Ch4 AT %I* : Int;
# //Term5_EL3004
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 5 (EL3004)^AI Standard Channel 1^Value'}
# I_Term5_EL3004_Ch1 AT %I* : Int;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 5 (EL3004)^AI Standard Channel 2^Value'}
# I_Term5_EL3004_Ch2 AT %I* : Int;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 5 (EL3004)^AI Standard Channel 3^Value'}
# I_Term5_EL3004_Ch3 AT %I* : Int;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 5 (EL3004)^AI Standard Channel 4^Value'}
# I_Term5_EL3004_Ch4 AT %I* : Int;
# //Term6_EL4004
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 6 (EL4004)^AO Outputs Channel 1^Analog output'}
# Q_Term6_EL4004_Ch1 AT %Q* : Int;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 6 (EL4004)^AO Outputs Channel 2^Analog output'}
# Q_Term6_EL4004_Ch2 AT %Q* : Int;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 6 (EL4004)^AO Outputs Channel 3^Analog output'}
# Q_Term6_EL4004_Ch3 AT %Q* : Int;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 6 (EL4004)^AO Outputs Channel 4^Analog output'}
# Q_Term6_EL4004_Ch4 AT %Q* : Int;
# //Term7_EL1008
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 7 (EL1008)^Channel 1^Input'}
# I_Term7_EL1008_Ch1 AT %I* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 7 (EL1008)^Channel 2^Input'}
# I_Term7_EL1008_Ch2 AT %I* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 7 (EL1008)^Channel 3^Input'}
# I_Term7_EL1008_Ch3 AT %I* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 7 (EL1008)^Channel 4^Input'}
# I_Term7_EL1008_Ch4 AT %I* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 7 (EL1008)^Channel 5^Input'}
# I_Term7_EL1008_Ch5 AT %I* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 7 (EL1008)^Channel 6^Input'}
# I_Term7_EL1008_Ch6 AT %I* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 7 (EL1008)^Channel 7^Input'}
# I_Term7_EL1008_Ch7 AT %I* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 7 (EL1008)^Channel 8^Input'}
# I_Term7_EL1008_Ch8 AT %I* : Bool;
# //Term8_EL1088
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 8 (EL1088)^Channel 1^Input'}
# I_Term8_EL1088_Ch1 AT %I* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 8 (EL1088)^Channel 2^Input'}
# I_Term8_EL1088_Ch2 AT %I* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 8 (EL1088)^Channel 3^Input'}
# I_Term8_EL1088_Ch3 AT %I* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 8 (EL1088)^Channel 4^Input'}
# I_Term8_EL1088_Ch4 AT %I* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 8 (EL1088)^Channel 5^Input'}
# I_Term8_EL1088_Ch5 AT %I* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 8 (EL1088)^Channel 6^Input'}
# I_Term8_EL1088_Ch6 AT %I* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 8 (EL1088)^Channel 7^Input'}
# I_Term8_EL1088_Ch7 AT %I* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 8 (EL1088)^Channel 8^Input'}
# I_Term8_EL1088_Ch8 AT %I* : Bool;
# //Term9_EL1088
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 9 (EL1088)^Channel 1^Input'}
# I_Term9_EL1088_Ch1 AT %I* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 9 (EL1088)^Channel 2^Input'}
# I_Term9_EL1088_Ch2 AT %I* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 9 (EL1088)^Channel 3^Input'}
# I_Term9_EL1088_Ch3 AT %I* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 9 (EL1088)^Channel 4^Input'}
# I_Term9_EL1088_Ch4 AT %I* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 9 (EL1088)^Channel 5^Input'}
# I_Term9_EL1088_Ch5 AT %I* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 9 (EL1088)^Channel 6^Input'}
# I_Term9_EL1088_Ch6 AT %I* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 9 (EL1088)^Channel 7^Input'}
# I_Term9_EL1088_Ch7 AT %I* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 9 (EL1088)^Channel 8^Input'}
# I_Term9_EL1088_Ch8 AT %I* : Bool;
# //Term11_EL2798
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 11 (EL2798)^Channel 1^Output'}
# Q_Term11_EL2798_Ch1 AT %Q* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 11 (EL2798)^Channel 2^Output'}
# Q_Term11_EL2798_Ch2 AT %Q* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 11 (EL2798)^Channel 3^Output'}
# Q_Term11_EL2798_Ch3 AT %Q* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 11 (EL2798)^Channel 4^Output'}
# Q_Term11_EL2798_Ch4 AT %Q* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 11 (EL2798)^Channel 5^Output'}
# Q_Term11_EL2798_Ch5 AT %Q* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 11 (EL2798)^Channel 6^Output'}
# Q_Term11_EL2798_Ch6 AT %Q* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 11 (EL2798)^Channel 7^Output'}
# Q_Term11_EL2798_Ch7 AT %Q* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 11 (EL2798)^Channel 8^Output'}
# Q_Term11_EL2798_Ch8 AT %Q* : Bool;
# //Term12_EL2798
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 12 (EL2798)^Channel 1^Output'}
# Q_Term12_EL2798_Ch1 AT %Q* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 12 (EL2798)^Channel 2^Output'}
# Q_Term12_EL2798_Ch2 AT %Q* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 12 (EL2798)^Channel 3^Output'}
# Q_Term12_EL2798_Ch3 AT %Q* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 12 (EL2798)^Channel 4^Output'}
# Q_Term12_EL2798_Ch4 AT %Q* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 12 (EL2798)^Channel 5^Output'}
# Q_Term12_EL2798_Ch5 AT %Q* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 12 (EL2798)^Channel 6^Output'}
# Q_Term12_EL2798_Ch6 AT %Q* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 12 (EL2798)^Channel 7^Output'}
# Q_Term12_EL2798_Ch7 AT %Q* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 12 (EL2798)^Channel 8^Output'}
# Q_Term12_EL2798_Ch8 AT %Q* : Bool;
# //Term10_EL1088
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 10 (EL1088)^Channel 1^Input'}
# I_Term10_EL1088_Ch1 AT %I* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 10 (EL1088)^Channel 2^Input'}
# I_Term10_EL1088_Ch2 AT %I* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 10 (EL1088)^Channel 3^Input'}
# I_Term10_EL1088_Ch3 AT %I* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 10 (EL1088)^Channel 4^Input'}
# I_Term10_EL1088_Ch4 AT %I* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 10 (EL1088)^Channel 5^Input'}
# I_Term10_EL1088_Ch5 AT %I* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 10 (EL1088)^Channel 6^Input'}
# I_Term10_EL1088_Ch6 AT %I* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 10 (EL1088)^Channel 7^Input'}
# I_Term10_EL1088_Ch7 AT %I* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^Term 1 (EK1200)^Term 10 (EL1088)^Channel 8^Input'}
# I_Term10_EL1088_Ch8 AT %I* : Bool;
# //EB3_EP4374
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^EB3 (EP4374-0002)^AI Inputs Channel 1^Value'}
# I_EB3_EP4374_Ch1 AT %I* : Int;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^EB3 (EP4374-0002)^AI Inputs Channel 2^Value'}
# I_EB3_EP4374_Ch2 AT %I* : Int;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^EB3 (EP4374-0002)^AO Outputs Channel 3^Analog output'}
# Q_EB3_EP4374_Ch3 AT %Q* : Int;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^EB3 (EP4374-0002)^AO Outputs Channel 4^Analog output'}
# Q_EB3_EP4374_Ch4 AT %Q* : Int;
# //EB4_EP2339
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^EB4 (EP2339-0021)^Channel 1^Input'}
# I_EB4_EP2339_Ch1 AT %I* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^EB4 (EP2339-0021)^Channel 2^Input'}
# I_EB4_EP2339_Ch2 AT %I* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^EB4 (EP2339-0021)^Channel 3^Input'}
# I_EB4_EP2339_Ch3 AT %I* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^EB4 (EP2339-0021)^Channel 4^Input'}
# I_EB4_EP2339_Ch4 AT %I* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^EB4 (EP2339-0021)^Channel 5^Input'}
# I_EB4_EP2339_Ch5 AT %I* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^EB4 (EP2339-0021)^Channel 6^Input'}
# I_EB4_EP2339_Ch6 AT %I* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^EB4 (EP2339-0021)^Channel 7^Input'}
# I_EB4_EP2339_Ch7 AT %I* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^EB4 (EP2339-0021)^Channel 8^Input'}
# I_EB4_EP2339_Ch8 AT %I* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^EB4 (EP2339-0021)^Channel 9^Input'}
# I_EB4_EP2339_Ch9 AT %I* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^EB4 (EP2339-0021)^Channel 10^Input'}
# I_EB4_EP2339_Ch10 AT %I* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^EB4 (EP2339-0021)^Channel 11^Input'}
# I_EB4_EP2339_Ch11 AT %I* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^EB4 (EP2339-0021)^Channel 12^Input'}
# I_EB4_EP2339_Ch12 AT %I* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^EB4 (EP2339-0021)^Channel 13^Input'}
# I_EB4_EP2339_Ch13 AT %I* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^EB4 (EP2339-0021)^Channel 14^Input'}
# I_EB4_EP2339_Ch14 AT %I* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^EB4 (EP2339-0021)^Channel 15^Input'}
# I_EB4_EP2339_Ch15 AT %I* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^EB4 (EP2339-0021)^Channel 16^Input'}
# I_EB4_EP2339_Ch16 AT %I* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^EB4 (EP2339-0021)^Channel 17^Output'}
# Q_EB4_EP2339_Ch17 AT %Q* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^EB4 (EP2339-0021)^Channel 18^Output'}
# Q_EB4_EP2339_Ch18 AT %Q* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^EB4 (EP2339-0021)^Channel 19^Output'}
# Q_EB4_EP2339_Ch19 AT %Q* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^EB4 (EP2339-0021)^Channel 20^Output'}
# Q_EB4_EP2339_Ch20 AT %Q* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^EB4 (EP2339-0021)^Channel 21^Output'}
# Q_EB4_EP2339_Ch21 AT %Q* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^EB4 (EP2339-0021)^Channel 22^Output'}
# Q_EB4_EP2339_Ch22 AT %Q* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^EB4 (EP2339-0021)^Channel 23^Output'}
# Q_EB4_EP2339_Ch23 AT %Q* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^EB4 (EP2339-0021)^Channel 24^Output'}
# Q_EB4_EP2339_Ch24 AT %Q* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^EB4 (EP2339-0021)^Channel 25^Output'}
# Q_EB4_EP2339_Ch25 AT %Q* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^EB4 (EP2339-0021)^Channel 26^Output'}
# Q_EB4_EP2339_Ch26 AT %Q* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^EB4 (EP2339-0021)^Channel 27^Output'}
# Q_EB4_EP2339_Ch27 AT %Q* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^EB4 (EP2339-0021)^Channel 28^Output'}
# Q_EB4_EP2339_Ch28 AT %Q* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^EB4 (EP2339-0021)^Channel 29^Output'}
# Q_EB4_EP2339_Ch29 AT %Q* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^EB4 (EP2339-0021)^Channel 30^Output'}
# Q_EB4_EP2339_Ch30 AT %Q* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^EB4 (EP2339-0021)^Channel 31^Output'}
# Q_EB4_EP2339_Ch31 AT %Q* : Bool;
# { attribute 'TcLinkTo':='TIID^GA PLC (EtherCAT)^EB4 (EP2339-0021)^Channel 32^Output'}
# Q_EB4_EP2339_Ch32 AT %Q* : Bool;
